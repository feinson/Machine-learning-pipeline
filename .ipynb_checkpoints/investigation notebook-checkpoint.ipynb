# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./data/clean_tabular_data.csv')

print(df.dtypes)
print(len(df.columns))
df.head()
# Out:
# ID                       object
# Category                 object
# Title                    object
# Description              object
# Amenities                object
# Location                 object
# guests                    int64
# beds                      int64
# bathrooms                 int64
# Price_Night               int64
# Cleanliness_rating      float64
# Accuracy_rating         float64
# Communication_rating    float64
# Location_rating         float64
# Check-in_rating         float64
# Value_rating            float64
# amenities_count         float64
# url                      object
# bedrooms                  int64
# dtype: object
# 19
#                                      ID    Category  \
# 0  f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1  1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2  d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3  ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4  cfe479b9-c8f8-44af-9bc6-46ede9f14bb5  Treehouses
#
#                                               Title  \
# 0                 Red Kite Tree Tent - Ynys Affalon
# 1    Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                       Cabane Entre Les Pins\n🌲🏕️🌲
# 3  Tree Top Cabin with log burner & private hot tub
# 4                       Treehouse near Paris Disney
#
#                                          Description  \
# 0  Escape to one of these two fabulous Tree Tents...
# 1  Come and spend a romantic stay with a couple o...
# 2  Rustic cabin between the pines, 3 meters high ...
# 3  The Tree top cabin is situated in our peaceful...
# 4  Charming cabin nestled in the leaves, real unu...
#
#                                            Amenities  \
# 0  BathroomShampooBedroom and laundryEssentialsTo...
# 1  Bedroom and laundryEssentialsTowels, bed sheet...
# 2  Scenic viewsGarden viewRiver viewBathroomClean...
# 3  BathroomHot waterBedroom and laundryEssentials...
# 4  BathroomHair dryerShampooHot waterShower gelBe...
#
#                                       Location  guests  beds  bathrooms  \
# 0             Llandrindod Wells United Kingdom       2     1          1
# 1                  Guyonvelle Grand Est France       3     3          0
# 2                     Duclair Normandie France       4     2          1
# 3                Barmouth Wales United Kingdom       2     1          1
# 4  Le Plessis-Feu-Aussoux Île-de-France France       4     3          1
#
#    Price_Night  Cleanliness_rating  Accuracy_rating  Communication_rating  \
# 0          105                 4.6              4.7                   4.3
# 1           92                 4.3              4.7                   4.6
# 2           52                 4.2              4.6                   4.8
# 3          132                 4.8              4.9                   4.9
# 4          143                 5.0              4.9                   5.0
#
#    Location_rating  Check-in_rating  Value_rating  amenities_count  \
# 0              5.0              4.3           4.3             13.0
# 1              4.9              4.7           4.5              8.0
# 2              4.8              4.8           4.7             51.0
# 3              4.9              5.0           4.6             23.0
# 4              4.7              5.0           4.7             32.0
#
#                                                  url  bedrooms
# 0  https://www.airbnb.co.uk/rooms/26620994?adults...         1
# 1  https://www.airbnb.co.uk/rooms/27055498?adults...         1
# 2  https://www.airbnb.co.uk/rooms/51427108?adults...         1
# 3  https://www.airbnb.co.uk/rooms/49543851?adults...         1
# 4  https://www.airbnb.co.uk/rooms/935398?adults=1...         2

# %%
def load_airbnb(clean_df: pd.DataFrame, label):
    df = clean_df.copy()
    labels = np.array(df.pop(label))
    features = np.array(df.select_dtypes(['number']))
    return (features, labels)

# %%
# Out:
# [(890, 11), (890,)]
